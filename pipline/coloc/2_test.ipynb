# %%
from finemap_tools.finemap.coloc import coloc_Wrapper

# %%
topLoci = (1, 15583355, 15583355)  # (chr, start, end)
locus_range = 200  # 100kb
locus_range = locus_range * 1000
locus_range_tuple = (topLoci[0], topLoci[1] - locus_range, topLoci[2] + locus_range)

locus_region = f"{locus_range_tuple[0]}:{locus_range_tuple[1]}-{locus_range_tuple[2]}"
print(f"locus_region: {locus_region}")
# Out:
# locus_region: 1:15383355-15783355

# %%
gwas_file = "/home/xutingfeng/GIFT/data/GWAS/T1Mapping_Cortex_20240129.csv_firstorder_Median_all_2023_GRCh38_unionKidneys.tsv.gz"
gwas2_file = (
    "/home/xutingfeng/GIFT/data/GWAS/CKD_overall_ALL_JW_20180223_nstud30.dbgap.tsv.gz"
)
save_dir = "/home/xutingfeng/GIFT/data/analysis/DNAJC16/coloc"
from pathlib import Path

Path(save_dir).mkdir(parents=True, exist_ok=True)
# eQTL_path = "/home/xutingfeng/GIFT/GTEx_V8/ge/Kidney_Cortex.tsv.gz"
eQTL_path = "/home/xutingfeng/GIFT/GTEx_V8/ge/Adipose_Subcutaneous.tsv.gz"

# %%
from finemap_tools.others.polyfun.polyfun_utils import (
    configure_logger,
)

configure_logger("./log.txt")

# %%
# test two sample coloc
coloc = coloc_Wrapper(
    sumstats_file=gwas_file,
    sumstats_file_format="pheweb",
    sumstats_file2=gwas2_file,
    sumstats_file2_format="pheweb",
    n1=4786,
    n2=73,
    type1="quant",
    type2="cc",
    sdY1=1,
    sdY2=None,
    chr_num=locus_range_tuple[0],
    start=locus_range_tuple[1],
    end=locus_range_tuple[2],
)
s1, s2, ld = coloc.finemap(
    num_causal_snps=1,
    out_dir="./test_two_gwas",
    ld_file="/home/xutingfeng/GIFT/data/analysis/DNAJC16/polyfun/ld/DNAJC16_GRCh38.1.14403350.15833356.npz",
)
# Out:
# [INFO]  Loading sumstats file...
# [INFO]  loading with normal tabix reader to loading sumstats file with /home/xutingfeng/GIFT/data/GWAS/T1Mapping_Cortex_20240129.csv_firstorder_Median_all_2023_GRCh38_unionKidneys.tsv.gz......
# Will load region from file.
# [INFO]  the header of loaded file is Index(['chrom', 'pos', 'ref', 'alt', 'pval', 'af', 'beta', 'sebeta'], dtype='object'), if it is not the correct header, please check the file or with correct format specified.
# [INFO]  Loaded sumstats for 3167 SNPs in 0.10 seconds
# [INFO]  filtering SNP by finemap_tools with 3167 SNP at begining........
# Function find_amibiguous_alleles elapsed time: 0.0225 seconds
# [INFO]  drop 380 ambiguous alleles
# Function find_Biallelic_snp elapsed time: 0.0024 seconds
# [INFO]  drop 2 biallelic snps
# [INFO]  after filtering, left 2785 SNP
# [INFO]  Loading sumstats file...
# [INFO]  loading with normal tabix reader to loading sumstats file with /home/xutingfeng/GIFT/data/GWAS/CKD_overall_ALL_JW_20180223_nstud30.dbgap.tsv.gz......
# Will load region from file.
# [INFO]  the header of loaded file is Index(['chrom', 'pos', 'ref', 'alt', 'pval', 'af', 'beta', 'sebeta',
#        'num_samples'],
#       dtype='object'), if it is not the correct header, please check the file or with correct format specified.
# [INFO]  Loaded sumstats for 1399 SNPs in 0.09 seconds
# [INFO]  filtering SNP by finemap_tools with 1399 SNP at begining........
# Function find_amibiguous_alleles elapsed time: 0.0117 seconds
# [INFO]  drop 183 ambiguous alleles
# Function find_Biallelic_snp elapsed time: 0.0014 seconds
# [INFO]  drop 0 biallelic snps
# [INFO]  after filtering, left 1216 SNP
# [INFO]  before sync , sumstats1 have 2785 SNPs, qtl have 1216 SNPs
# [INFO]  after sync,sumstats1 left 739 SNPs, qtl 739 SNPs
# [INFO]  df_sumstats2 finally inlcude 739 rows
# [INFO]  cffi mode is CFFI_MODE.ANY
# [DEBUG]  Looking for R home with: R RHOME
# [INFO]  R home found: /home/xutingfeng/miniforge3/envs/finemap/lib/R
# [DEBUG]  Looking for LD_LIBRARY_PATH with: /home/xutingfeng/miniforge3/envs/finemap/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# [INFO]  R library path:
# [INFO]  LD_LIBRARY_PATH:
# [DEBUG]  cffi mode is InterfaceType.API
# [INFO]  Default options to initialize R: rpy2, --quiet, --no-save
# [INFO]  R is already initialized. No need to initialize.
# [WARNING]  R[write to console]: This is coloc version 5.2.3
#
# [WARNING]  R[write to console]:
# Attaching package: ‘dplyr’
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# [WARNING]  R[write to console]:
#
# [WARNING]  R[write to console]: Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# [WARNING]  R[write to console]: clusterProfiler v4.2.2  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
# [WARNING]  R[write to console]:
# Attaching package: ‘clusterProfiler’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:stats’:
#
#     filter
#
#
# [WARNING]  R[write to console]: Loading required package: AnnotationDbi
#
# [WARNING]  R[write to console]: Loading required package: stats4
#
# [WARNING]  R[write to console]: Loading required package: BiocGenerics
#
# [WARNING]  R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# [WARNING]  R[write to console]: Loading required package: Biobase
#
# [WARNING]  R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# [WARNING]  R[write to console]: Loading required package: IRanges
#
# [WARNING]  R[write to console]: Loading required package: S4Vectors
#
# [WARNING]  R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# [WARNING]  R[write to console]:
# Attaching package: ‘IRanges’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# [WARNING]  R[write to console]:
# Attaching package: ‘AnnotationDbi’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# [WARNING]  R[write to console]:
#
# [INFO]  run coloc with two sumstats files: gwas and eQTL
# [1] "Number of SNPs in common:739"
# [1] "ld_df is not provided, using coloc.abf"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.48e-34  2.69e-35  8.36e-01  1.52e-01  1.25e-02
# [1] "PP abf for shared variant: 1.25%"
# [1] "Finish coloc.abf"
#        nsnps    PP.H0.abf    PP.H1.abf    PP.H2.abf    PP.H3.abf    PP.H4.abf
# 7.390000e+02 1.479572e-34 2.688340e-35 8.356840e-01 1.518288e-01 1.248715e-02
# [WARNING]  R[write to console]: Results fail decision rule H4 > 0.95
#
# [WARNING]  R[write to console]: Error in `[.data.frame`(merged_data, , c("rsid", paste0("pvalue_", sumstats1_suffix))) :
#   undefined columns selected
#
# [WARNING]  R[write to console]: In addition:
# [WARNING]  R[write to console]: Warning message:
#
# [WARNING]  R[write to console]: In check_dataset(d = dataset1, 1) :
# [WARNING]  R[write to console]:  minimum p value is: 7.1148e-05
# If this is what you expected, this is not a problem.
# If this is not as small as you expected, please check you supplied var(beta) and not sd(beta) for the varbeta argument. If that's not the explanation, please check the 02_data vignette.
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[5], line 17
#       1 # test two sample coloc
#       2 coloc = coloc_Wrapper(
#       3     sumstats_file=gwas_file,
#       4     sumstats_file_format="pheweb",
#    (...)
#      15     end=locus_range_tuple[2],
#      16 )
# ---> 17 s1, s2, ld = coloc.finemap(
#      18     num_causal_snps=1,
#      19     out_dir="./test_two_gwas",
#      20     ld_file="/home/xutingfeng/GIFT/data/analysis/DNAJC16/polyfun/ld/DNAJC16_GRCh38.1.14403350.15833356.npz",
#      21 )
#
# File ~/github_code/mine/finemap_tools/finemap_tools/finemap/coloc.py:602, in coloc_Wrapper.finemap(self, num_causal_snps, out_dir, gene_col, ld_file, verbose, allow_missing, save_all)
#     590     assert (
#     591         self.df_ld.shape[0]
#     592         == self.df_ld.shape[1]
#     593         == self.df_sumstats.shape[0]
#     594         == self.df_sumstats2.shape[0]
#     595     )
#     596     assert (
#     597         self.df_ld.index.tolist()
#     598         == self.df_ld.columns.tolist()
#     599         == self.df_sumstats.index.tolist()
#     600         == self.df_sumstats2.index.tolist()
#     601     )
# --> 602 res = r.coloc_analysis(
#     603     sumstats1=self.df_sumstats,
#     604     sumstats2=self.df_sumstats2,
#     605     output_folder=current_output,
#     606     n1=self.n1,
#     607     n2=self.n2,
#     608     sdY1=self.sdY1,
#     609     sdY2=self.sdY2,
#     610     type1=self.type1,
#     611     type2=self.type2,
#     612     num_causal_snps=num_causal_snps,
#     613     ld_df=self.ld_df if num_causal_snps > 1 else None,
#     614     sumstats1_suffix=self.sumstats_file_suffix,
#     615     sumstats2_suffix=self.sumstats_file2_suffix,
#     616 )
#     618 res_gene_df = res["coloc_res"]
#     619 res_snp_df = res["coloc_snp_res"]
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     206         v = kwargs.pop(k)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     129     else:
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#     133 return res
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     810     res = rmemory.protect(
#     811         openrlib.rlib.R_tryEval(
#     812             call_r,
#     813             call_context.__sexp__._cdata,
#     814             error_occured)
#     815     )
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in `[.data.frame`(merged_data, , c("rsid", paste0("pvalue_", sumstats1_suffix))) :
#   undefined columns selected

# %%
coloc = coloc_Wrapper(
    sumstats_file=gwas_file,
    sumstats_file_format="pheweb",
    sumstats_file2=eQTL_path,
    sumstats_file2_format="GTExV8",
    n1=4786,
    n2=73,
    type1="quant",
    type2="quant",
    sdY1=1,
    sdY2=None,
    chr_num=locus_range_tuple[0],
    start=locus_range_tuple[1],
    end=locus_range_tuple[2],
)
s1 = coloc.finemap(
    num_causal_snps=1,
    out_dir="./test",
)
# Out:
# [INFO]  Loading sumstats file...
# [INFO]  loading with normal tabix reader to loading sumstats file with /home/xutingfeng/GIFT/data/GWAS/T1Mapping_Cortex_20240129.csv_firstorder_Median_all_2023_GRCh38_unionKidneys.tsv.gz......
# Will load region from file.
# [INFO]  the header of loaded file is Index(['chrom', 'pos', 'ref', 'alt', 'pval', 'af', 'beta', 'sebeta'], dtype='object'), if it is not the correct header, please check the file or with correct format specified.
# [INFO]  Loaded sumstats for 3167 SNPs in 0.12 seconds
# [INFO]  filtering SNP by finemap_tools with 3167 SNP at begining........
# Function find_amibiguous_alleles elapsed time: 0.0270 seconds
# [INFO]  drop 380 ambiguous alleles
# Function find_Biallelic_snp elapsed time: 0.0717 seconds
# [INFO]  drop 2 biallelic snps
# [INFO]  after filtering, left 2785 SNP
# [INFO]  loading GTExV8 format sumstats file with /home/xutingfeng/GIFT/GTEx_V8/ge/Adipose_Subcutaneous.tsv.gz......
# Will load region from file.
# [INFO]  the header of loaded file is Index(['variant', 'r2', 'pvalue', 'molecular_trait_object_id',
#        'molecular_trait_id', 'maf', 'gene_id', 'median_tpm', 'beta', 'se',
#        'an', 'ac', 'chromosome', 'position', 'ref', 'alt', 'type', 'rsid'],
#       dtype='object'), if it is not the correct header, please check the file or with correct format specified.
# [INFO]  filtering SNP by finemap_tools with 62822 SNP at begining........
# Function find_amibiguous_alleles elapsed time: 0.4842 seconds
# [INFO]  drop 7285 ambiguous alleles
# Function find_Biallelic_snp elapsed time: 0.0023 seconds
# [INFO]  drop 1 biallelic snps
# [INFO]  after filtering, left 55491 SNP
# [INFO]  na numbers in sumstats Adipose_Subcutaneous.tsv.gz: 0
# [INFO]  before sync , sumstats1 have 2785 SNPs, qtl have 55491 SNPs
# [INFO]  after sync,sumstats1 left 1314 SNPs, qtl 54597 SNPs
# [INFO]  df_sumstats2 finally inlcude 54597 rows
# [INFO]  run coloc with ENSG00000037637 as xQTL
# [INFO]  run coloc with 1314 SNPs
# [1] "gene_id column found in sumstats2, using gene_id to split the data"
# [1] "Number of SNPs in common:1314"
# [1] "ld_df is not provided, using coloc.abf"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.02e-15  1.47e-16  7.12e-01  1.02e-01  1.86e-01
# [1] "PP abf for shared variant: 18.6%"
# [1] "Finish coloc.abf"
#        nsnps    PP.H0.abf    PP.H1.abf    PP.H2.abf    PP.H3.abf    PP.H4.abf
# 1.314000e+03 1.021562e-15 1.472813e-16 7.120205e-01 1.024683e-01 1.855112e-01
# [WARNING]  R[write to console]: Results fail decision rule H4 > 0.95
#
# Joining with `by = join_by(snp)`
#  [1] "chr"                       "position"
#  [3] "beta_gwas"                 "varbeta_gwas"
#  [5] "sebeta"                    "alt"
#  [7] "ref"                       "variant"
#  [9] "r2"                        "pvalue_gwas"
# [11] "molecular_trait_object_id" "molecular_trait_id"
# [13] "maf"                       "gene_id"
# [15] "median_tpm"                "an"
# [17] "ac"                        "type"
# [19] "rsid"                      "snp"
# [21] "snpidx"                    "beta_eQTL"
# [23] "varbeta_eQTL"              "pvalue_eQTL"
# [25] "SNP.PP.H4"
# o{'coloc_res': o{'nsnps': [1314.], 'PP.H0.abf': [1.02156234e-15], 'PP.H1.abf': [1.47281273e-16], 'PP.H2.abf': [0.71202052], 'PP.H3.abf': [0.10246832], 'PP.H4.abf': [0.18551116], 'is_significant': [1] FALSE
# , }, 'coloc_snp_res': Empty DataFrame
# Columns: [chr, position, beta_gwas, varbeta_gwas, sebeta, alt, ref, variant, r2, pvalue_gwas, molecular_trait_object_id, molecular_trait_id, maf, gene_id, median_tpm, an, ac, type, rsid, snp, snpidx, beta_eQTL, varbeta_eQTL, pvalue_eQTL, SNP.PP.H4]
# Index: []
#
# [0 rows x 25 columns], }
# <class 'rpy2.rlike.container.OrdDict'>
# [INFO]  run coloc with ENSG00000055070 as xQTL
# [INFO]  run coloc with 1314 SNPs
# [1] "gene_id column found in sumstats2, using gene_id to split the data"
# [1] "Number of SNPs in common:1314"
# [1] "ld_df is not provided, using coloc.abf"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.33e-15  7.77e-17  9.29e-01  5.41e-02  1.69e-02
# [1] "PP abf for shared variant: 1.69%"
# [1] "Finish coloc.abf"
#        nsnps    PP.H0.abf    PP.H1.abf    PP.H2.abf    PP.H3.abf    PP.H4.abf
# 1.314000e+03 1.332852e-15 7.766157e-17 9.289867e-01 5.411258e-02 1.690068e-02
# [WARNING]  R[write to console]: Results fail decision rule H4 > 0.95
#
# Joining with `by = join_by(snp)`
#  [1] "chr"                       "position"
#  [3] "beta_gwas"                 "varbeta_gwas"
#  [5] "sebeta"                    "alt"
#  [7] "ref"                       "variant"
#  [9] "r2"                        "pvalue_gwas"
# [11] "molecular_trait_object_id" "molecular_trait_id"
# [13] "maf"                       "gene_id"
# [15] "median_tpm"                "an"
# [17] "ac"                        "type"
# [19] "rsid"                      "snp"
# [21] "snpidx"                    "beta_eQTL"
# [23] "varbeta_eQTL"              "pvalue_eQTL"
# [25] "SNP.PP.H4"
# o{'coloc_res': o{'nsnps': [1314.], 'PP.H0.abf': [1.33285185e-15], 'PP.H1.abf': [7.7661574e-17], 'PP.H2.abf': [0.92898674], 'PP.H3.abf': [0.05411258], 'PP.H4.abf': [0.01690068], 'is_significant': [1] FALSE
# , }, 'coloc_snp_res': Empty DataFrame
# Columns: [chr, position, beta_gwas, varbeta_gwas, sebeta, alt, ref, variant, r2, pvalue_gwas, molecular_trait_object_id, molecular_trait_id, maf, gene_id, median_tpm, an, ac, type, rsid, snp, snpidx, beta_eQTL, varbeta_eQTL, pvalue_eQTL, SNP.PP.H4]
# Index: []
#
# [0 rows x 25 columns], }
# <class 'rpy2.rlike.container.OrdDict'>
# [INFO]  run coloc with ENSG00000065526 as xQTL
# [INFO]  run coloc with 1314 SNPs
# [1] "gene_id column found in sumstats2, using gene_id to split the data"
# [1] "Number of SNPs in common:1314"
# [1] "ld_df is not provided, using coloc.abf"
# PP.H0.abf PP.H1.abf PP.H2.abf PP.H3.abf PP.H4.abf
#  1.32e-15  8.30e-17  9.22e-01  5.78e-02  1.97e-02
# [1] "PP abf for shared variant: 1.97%"
# [1] "Finish coloc.abf"
#        nsnps    PP.H0.abf    PP.H1.abf    PP.H2.abf    PP.H3.abf    PP.H4.abf
# 1.314000e+03 1.323469e-15 8.299702e-17 9.224470e-01 5.782851e-02 1.972448e-02
# [WARNING]  R[write to console]: Results fail decision rule H4 > 0.95

# %%
# coloc = coloc_Wrapper(
#     sumstats_file=gwas_file,
#     sumstats_file_format="pheweb",
#     sumstats_file2=eQTL_path,
#     sumstats_file2_format="GTExV8",
#     n1=4786,
#     n2=73,
#     type1="quant",
#     type2="quant",
#     sdY1=1,
#     sdY2=None,
#     chr_num=locus_range_tuple[0],
#     start=locus_range_tuple[1],
#     end=locus_range_tuple[2],
# )
# s1 = coloc.finemap(
#     num_causal_snps=2,
#     out_dir="./test",
#     ld_file="/home/xutingfeng/GIFT/data/analysis/DNAJC16/polyfun/ld/DNAJC16_GRCh38.1.14403350.15833356.npz",
#     allow_missing=True,
# )
# Out:
# [INFO]  Loading sumstats file...
# [INFO]  loading with normal tabix reader to loading sumstats file with /home/xutingfeng/GIFT/data/GWAS/T1Mapping_Cortex_20240129.csv_firstorder_Median_all_2023_GRCh38_unionKidneys.tsv.gz......
# Will load region from file.
# [INFO]  the header of loaded file is Index(['chrom', 'pos', 'ref', 'alt', 'pval', 'af', 'beta', 'sebeta'], dtype='object'), if it is not the correct header, please check the file or with correct format specified.
# [INFO]  Loaded sumstats for 3167 SNPs in 0.11 seconds
# [INFO]  filtering SNP by finemap_tools with 3167 SNP at begining........
# Function find_amibiguous_alleles elapsed time: 0.0251 seconds
# [INFO]  drop 380 ambiguous alleles
# Function find_Biallelic_snp elapsed time: 0.0022 seconds
# [INFO]  drop 2 biallelic snps
# [INFO]  after filtering, left 2785 SNP
# [INFO]  loading GTExV8 format sumstats file with /home/xutingfeng/GIFT/GTEx_V8/ge/Adipose_Subcutaneous.tsv.gz......
# Will load region from file.
# [INFO]  the header of loaded file is Index(['variant', 'r2', 'pvalue', 'molecular_trait_object_id',
#        'molecular_trait_id', 'maf', 'gene_id', 'median_tpm', 'beta', 'se',
#        'an', 'ac', 'chromosome', 'position', 'ref', 'alt', 'type', 'rsid'],
#       dtype='object'), if it is not the correct header, please check the file or with correct format specified.
# [INFO]  filtering SNP by finemap_tools with 62822 SNP at begining........
# Function find_amibiguous_alleles elapsed time: 0.4110 seconds
# [INFO]  drop 7285 ambiguous alleles
# Function find_Biallelic_snp elapsed time: 0.0019 seconds
# [INFO]  drop 1 biallelic snps
# [INFO]  after filtering, left 55491 SNP
# [INFO]  na numbers in sumstats Adipose_Subcutaneous.tsv.gz: 0
# [INFO]  run coloc with 2 causal SNPs, this will run coloc.susie
# [INFO]  Loading LD file /home/xutingfeng/GIFT/data/analysis/DNAJC16/polyfun/ld/DNAJC16_GRCh38.1.14403350.15833356
# [INFO]  Done in 5.79 seconds
# [WARNING]  there are 10291 nan in R matrix in the ld_arr
# [INFO]  remove 0 SNPs with NaNs in LD, this should be think carefully.
# [WARNING]  15 variants with sumstats were not found in the LD file and will be omitted (please note that this may lead to false positives if the omitted SNPs are causal!)
# [WARNING]  4 of the missing variants were indels. Check that the allele order (A1/A2) matches between the sumstats and the LD file. Also see the flag --allow-swapped-indel-alleles
# [INFO]  before sync , sumstats1 have 2785 SNPs, qtl have 55491 SNPs
# [INFO]  after sync,sumstats1 left 1314 SNPs, qtl 54597 SNPs
# [INFO]  df_sumstats2 finally inlcude 54597 rows
# [INFO]  cffi mode is CFFI_MODE.ANY
# [DEBUG]  Looking for R home with: R RHOME
# [INFO]  R home found: /home/xutingfeng/miniforge3/envs/finemap/lib/R
# [DEBUG]  Looking for LD_LIBRARY_PATH with: /home/xutingfeng/miniforge3/envs/finemap/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# [INFO]  R library path:
# [INFO]  LD_LIBRARY_PATH:
# [DEBUG]  cffi mode is InterfaceType.API
# [INFO]  Default options to initialize R: rpy2, --quiet, --no-save
# [INFO]  R is already initialized. No need to initialize.
# [WARNING]  R[write to console]: This is coloc version 5.2.3
#
# [WARNING]  R[write to console]:
# Attaching package: ‘dplyr’
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# [WARNING]  R[write to console]:
#
# [WARNING]  R[write to console]: Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# [WARNING]  R[write to console]: clusterProfiler v4.2.2  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
# [WARNING]  R[write to console]:
# Attaching package: ‘clusterProfiler’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:stats’:
#
#     filter
#
#
# [WARNING]  R[write to console]: Loading required package: AnnotationDbi
#
# [WARNING]  R[write to console]: Loading required package: stats4
#
# [WARNING]  R[write to console]: Loading required package: BiocGenerics
#
# [WARNING]  R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# [WARNING]  R[write to console]: Loading required package: Biobase
#
# [WARNING]  R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# [WARNING]  R[write to console]: Loading required package: IRanges
#
# [WARNING]  R[write to console]: Loading required package: S4Vectors
#
# [WARNING]  R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:clusterProfiler’:
#
#     rename
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# [WARNING]  R[write to console]:
# Attaching package: ‘IRanges’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:clusterProfiler’:
#
#     slice
#
#
# [WARNING]  R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# [WARNING]  R[write to console]:
# Attaching package: ‘AnnotationDbi’
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:clusterProfiler’:
#
#     select
#
#
# [WARNING]  R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# [WARNING]  R[write to console]:
#
# [INFO]  run coloc with ENSG00000037637 as xQTL
# [1] "gene_id column found in sumstats2, using gene_id to split the data"
# [1] "Number of SNPs in common:1311"
# [1] 1311 1311
# [1] 1311   24
# [WARNING]  R[write to console]: running max iterations: 100
#
# [WARNING]  R[write to console]: 	converged: TRUE
#
# [WARNING]  R[write to console]: running max iterations: 100
#
# [WARNING]  R[write to console]: 	converged: TRUE
#
# NULL
# [WARNING]  R[write to console]: Error in (function (sumstats1, sumstats2, output_folder, n1, n2, sdY1,  :
#   object 're' not found
#
# [WARNING]  R[write to console]: In addition:
# [WARNING]  R[write to console]: Warning messages:
#
# [WARNING]  R[write to console]: 1:
# [WARNING]  R[write to console]: In check_dataset(dataset1) :
# [WARNING]  R[write to console]:  minimum p value is: 0.0030845
# If this is what you expected, this is not a problem.
# If this is not as small as you expected, please check you supplied var(beta) and not sd(beta) for the varbeta argument. If that's not the explanation, please check the 02_data vignette.
#
# [WARNING]  R[write to console]: 2:
# [WARNING]  R[write to console]: In check_dataset(d, suffix, req = c("beta", "varbeta", "LD", "snp",  :
# [WARNING]  R[write to console]:
#
# [WARNING]  R[write to console]:  minimum p value is: 0.0030845
# If this is what you expected, this is not a problem.
# If this is not as small as you expected, please check you supplied var(beta) and not sd(beta) for the varbeta argument. If that's not the explanation, please check the 02_data vignette.
#
# [WARNING]  R[write to console]: 3: ggrepel: 1 unlabeled data points (too many overlaps). Consider increasing max.overlaps
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[7], line 16
#       1 coloc = coloc_Wrapper(
#       2     sumstats_file=gwas_file,
#       3     sumstats_file_format="pheweb",
#    (...)
#      14     end=locus_range_tuple[2],
#      15 )
# ---> 16 s1 = coloc.finemap(
#      17     num_causal_snps=2,
#      18     out_dir="./test",
#      19     ld_file="/home/xutingfeng/GIFT/data/analysis/DNAJC16/polyfun/ld/DNAJC16_GRCh38.1.14403350.15833356.npz",
#      20     allow_missing=True,
#      21 )
#
# File ~/github_code/mine/finemap_tools/finemap_tools/finemap/coloc.py:506, in finemap(self, num_causal_snps, out_dir, gene_col, ld_file, verbose, allow_missing, save_all)
#     504     )
#     505 logging.info(f""
# --> 506 current_res = r.coloc_analysis(
#     507     sumstats1=current_df1,
#     508     sumstats2=current_df2,
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     206         v = kwargs.pop(k)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     129     else:
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#     133 return res
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#      47     return _cdata_to_rinterface(cdata)
#
# File ~/miniforge3/envs/finemap/lib/python3.8/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     810     res = rmemory.protect(
#     811         openrlib.rlib.R_tryEval(
#     812             call_r,
#     813             call_context.__sexp__._cdata,
#     814             error_occured)
#     815     )
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in (function (sumstats1, sumstats2, output_folder, n1, n2, sdY1,  :
#   object 're' not found

# %%
import pandas as pd

pd.DataFrame(range(10)).reset_index(drop=False, names=["a"])
# Out:
#    a  0
# 0  0  0
# 1  1  1
# 2  2  2
# 3  3  3
# 4  4  4
# 5  5  5
# 6  6  6
# 7  7  7
# 8  8  8
# 9  9  9

# %%
ld.loc[common, common]

# %%
ld.reset_index(drop=False).to_feather(f"{save_dir}/ld.feather")

# %%
from rpy2 import robjects

robjects.r("NULL")

# %%
ld.index.name = ""
ld.columns.name = ""
ld

# %%
coloc.sumstats_file2[coloc.sumstats_file2["gene_id"] == "ENSG00000132906"].sort_values(
    "pvalue"
)

# %%
coloc.sumstats_file2["gene_id"].unique().shape

# %%
gene_col = "gene_id"
# drop duplicated SNPs
sumstats1_duplicated_num = coloc.sumstats_file1.duplicated(subset=["snp"]).sum()
sumstats2_duplicated_num = coloc.sumstats_file2.duplicated(
    subset=["snp", gene_col]
).sum()

# %%
# if sumstats1_duplicated_num > 0:
#     logging.warning(
#         f"sumstats1 have {sumstats1_duplicated_num} duplicated SNPs and will be dropped"
#     )
# if sumstats2_duplicated_num > 0:
#     logging.warning(
#         f"sumstats2 have {sumstats2_duplicated_num} duplicated SNPs and will be dropped"
#     )

coloc.sumstats_file1 = coloc.sumstats_file1.drop_duplicates(subset=["snp"])
coloc.sumstats_file2 = coloc.sumstats_file2.drop_duplicates(subset=["snp", gene_col])

assert (
    coloc.sumstats_file1.shape[0] > 0 and coloc.sumstats_file2.shape[0] > 0
), "no valid SNPs to run coloc after drop duplicated SNPs"

# sync sumstats
coloc.sync_sumstats()

# %%
coloc.sumstats_file2

# %%
drop_duplicated
